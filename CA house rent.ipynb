# %%
# importing all dependencies
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# %%
# load data set
ca_rent_price = pd.read_csv("price.csv")

# %%
ca_rent_price
# Out:
#        City Code                 City         Metro        County State  \
# 0           6181             New York      New York        Queens    NY
# 1          12447          Los Angeles   Los Angeles   Los Angeles    CA
# 2          17426              Chicago       Chicago          Cook    IL
# 3          39051              Houston       Houston        Harris    TX
# 4          13271         Philadelphia  Philadelphia  Philadelphia    PA
# ...          ...                  ...           ...           ...   ...
# 13126     397405    Highland Township    Gettysburg         Adams    PA
# 13127     398292  Town of Wrightstown     Green Bay         Brown    WI
# 13128     398343               Urbana       Corning       Steuben    NY
# 13129     398839               Angels           NaN     Calaveras    CA
# 13130     737788      Lebanon Borough      New York     Hunterdon    NJ
#
#        Population Rank  November 2010  December 2010  January 2011  \
# ...

# %%
# Get the total amount of data in the file

# %%
# performing EDA - data properties 
# shape ( num of rows, num of columns)
ca_rent_price.shape
# Out:
# (13131, 81)

# %%
# displays the first few rows of the dataframe
ca_rent_price.head()
# Out:
#    City Code          City         Metro        County State  Population Rank  \
# 0       6181      New York      New York        Queens    NY                1
# 1      12447   Los Angeles   Los Angeles   Los Angeles    CA                2
# 2      17426       Chicago       Chicago          Cook    IL                3
# 3      39051       Houston       Houston        Harris    TX                4
# 4      13271  Philadelphia  Philadelphia  Philadelphia    PA                5
#
#    November 2010  December 2010  January 2011  February 2011  ...  April 2016  \
# 0            NaN            NaN           NaN            NaN  ...        2334
# 1         2184.0         2184.0        2183.0         2188.0  ...        2637
# 2         1563.0         1555.0        1547.0         1537.0  ...        1684
# 3         1198.0         1199.0        1199.0         1200.0  ...        1444
# 4         1092.0         1099.0        1094.0         1087.0  ...        1206
#
# ...

# %%
# check missing values in a data DATA CLEANING 
ca_rent_price.isna().sum()
# Out:
# City Code            0
# City                 0
# Metro             1232
# County               0
# State                0
#                   ...
# September 2016       0
# October 2016         0
# November 2016        0
# December 2016        0
# January 2017         0
# Length: 81, dtype: int64

# %%
# collect the total num of rows with missing values - DATA CLEANING
(ca_rent_price.isna().sum().sum() / ca_rent_price.shape[0] * 100)
# Out:
# 194.09032061533776

# %%
# check the new rows and columns after drop - DATA CLEANING
ca_rent_price.shape
# Out:
# (13131, 81)

# %%
# check for duplicates - DATA CLEANING 
ca_rent_price.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13126    False
# 13127    False
# 13128    False
# 13129    False
# 13130    False
# Length: 13131, dtype: bool

# %%
ca_rent_price.duplicated().sum()
# Out:
# 0

# %%
# filter dataset to LA only 
ca_rent_price_la = ca_rent_price.loc[ca_rent_price['City'] == 'Los Angeles']

# %%
# drop the rows with missing values 
ca_rent_price = ca_rent_price.dropna()

# %%
ca_rent_price_la
# Out:
#    City Code         City        Metro       County State  Population Rank  \
# 1      12447  Los Angeles  Los Angeles  Los Angeles    CA                2
#
#    November 2010  December 2010  January 2011  February 2011  ...  April 2016  \
# 1         2184.0         2184.0        2183.0         2188.0  ...        2637
#
#    May 2016  June 2016  July 2016  August 2016  September 2016  October 2016  \
# 1      2662       2687       2704         2716            2723          2731
#
#    November 2016  December 2016  January 2017
# 1           2740           2748          2753
#
# [1 rows x 81 columns]

# %%
print(ca_rent_price_la.head())
# Out:
#    City Code         City        Metro       County State  Population Rank  \
# 1      12447  Los Angeles  Los Angeles  Los Angeles    CA                2
#
#    November 2010  December 2010  January 2011  February 2011  ...  April 2016  \
# 1         2184.0         2184.0        2183.0         2188.0  ...        2637
#
#    May 2016  June 2016  July 2016  August 2016  September 2016  October 2016  \
# 1      2662       2687       2704         2716            2723          2731
#
#    November 2016  December 2016  January 2017
# 1           2740           2748          2753
#
# [1 rows x 81 columns]

# %%
print(ca_rent_price_la.tail())
# Out:
#    City Code         City        Metro       County State  Population Rank  \
# 1      12447  Los Angeles  Los Angeles  Los Angeles    CA                2
#
#    November 2010  December 2010  January 2011  February 2011  ...  April 2016  \
# 1         2184.0         2184.0        2183.0         2188.0  ...        2637
#
#    May 2016  June 2016  July 2016  August 2016  September 2016  October 2016  \
# 1      2662       2687       2704         2716            2723          2731
#
#    November 2016  December 2016  January 2017
# 1           2740           2748          2753
#
# [1 rows x 81 columns]
